# %% [markdown]
# # Length of Stay Data Exploration
#
# Load and explore the first 10 rows of the LengthOfStay dataset.

# %%
import pandas as pd

# Load the first 10 rows of the CSV file
csv_path = 'data/LengthOfStay.csv'
df = pd.read_csv(csv_path, nrows=10)

print(f"Loaded {len(df)} rows")
print(f"\nColumns: {df.columns.tolist()}")
print(f"\nData shape: {df.shape}")
print(f"\nFirst 10 rows:")
df
# Out:
# Loaded 10 rows
#
# Columns: ['eid', 'vdate', 'rcount', 'gender', 'dialysisrenalendstage', 'asthma', 'irondef', 'pneum', 'substancedependence', 'psychologicaldisordermajor', 'depress', 'psychother', 'fibrosisandother', 'malnutrition', 'hemo', 'hematocrit', 'neutrophils', 'sodium', 'glucose', 'bloodureanitro', 'creatinine', 'bmi', 'pulse', 'respiration', 'secondarydiagnosisnonicd9', 'discharged', 'facid', 'lengthofstay']
#
# Data shape: (10, 28)
#
# First 10 rows:
#    eid       vdate rcount gender  dialysisrenalendstage  asthma  irondef  \
# 0    1   8/29/2012      0      F                      0       0        0
# 1    2   5/26/2012     5+      F                      0       0        0
# 2    3   9/22/2012      1      F                      0       0        0
# 3    4    8/9/2012      0      F                      0       0        0
# 4    5  12/20/2012      0      F                      0       0        0
# 5    6  11/27/2012      3      M                      0       0        0
# ...
